# %%
import pandas as pd

# %%
reaction= pd.read_excel(r"C:\Users\Vrushali Patil\OneDrive\Accenture Forage\Working\Reactions (1).xlsx")

# %%
reaction.head()
# Out:
#    Sr                            Content ID  \
# 0   0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1   1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2   2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3   3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4   4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type            Datetime
# 0                                   NaN      NaN 2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust 2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike 2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared 2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust 2021-01-06 19:13:01

# %%
content=pd.read_excel(r"C:\Users\Vrushali Patil\OneDrive\Accenture Forage\Working\Content (1).xlsx")

# %%
content.head()
# Out:
#    Sr                            Content ID  \
# 0   0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1   1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2   2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3   3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4   4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
left_join=pd.merge(reaction,content,on='Content ID',how='left')

# %%
left_join.head()
# Out:
#    Sr_x                            Content ID  \
# 0     0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1     1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2     2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3     3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4     4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                               User ID_x   Type_x            Datetime  Sr_y  \
# 0                                   NaN      NaN 2021-04-22 15:17:15     0
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust 2020-11-07 09:43:50     0
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike 2021-06-17 12:22:51     0
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared 2021-04-18 05:13:58     0
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust 2021-01-06 19:13:01     0
#
#                               User ID_y Type_y  Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo  Studying
# ...

# %%
left_join.rename(columns={'Type_x': 'Type','Type_y': 'Content_Type','User ID_y':'User ID'}, inplace=True)
left_join.head()
# Out:
#    Sr_x                            Content ID  \
# 0     0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1     1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2     2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3     3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4     4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                               User ID_x     Type            Datetime  Sr_y  \
# 0                                   NaN      NaN 2021-04-22 15:17:15     0
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust 2020-11-07 09:43:50     0
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike 2021-06-17 12:22:51     0
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared 2021-04-18 05:13:58     0
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust 2021-01-06 19:13:01     0
#
#                                 User ID Content_Type  Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# ...

# %%
left_join.drop(['Sr_x','User ID_x','Sr_y','URL'], inplace=True, axis=1)

# %%
left_join.head()
# Out:
#                              Content ID     Type            Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2      NaN 2021-04-22 15:17:15
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust 2020-11-07 09:43:50
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  dislike 2021-06-17 12:22:51
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2   scared 2021-04-18 05:13:58
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust 2021-01-06 19:13:01
#
#                                 User ID Content_Type  Category
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying

# %%
Reaction_types= pd.read_excel(r"C:\Users\Vrushali Patil\OneDrive\Accenture Forage\Working\ReactionTypes (1).xlsx")

# %%
Reaction_types.head()
# Out:
#    Sr        Type Sentiment  Score
# 0   0       heart  positive     60
# 1   1        want  positive     70
# 2   2     disgust  negative      0
# 3   3        hate  negative      5
# 4   4  interested  positive     30

# %%
Answer=pd.merge(left_join,Reaction_types,on='Type',how='left')

# %%
Answer["Category"].str.replace("Animals", "animals", case = False)
# Out:
# 0          Studying
# 1          Studying
# 2          Studying
# 3          Studying
# 4          Studying
#             ...
# 25548    technology
# 25549    technology
# 25550    technology
# 25551    technology
# 25552    technology
# Name: Category, Length: 25553, dtype: object

# %%
Answer.head()
# Out:
#                              Content ID     Type            Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2      NaN 2021-04-22 15:17:15
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust 2020-11-07 09:43:50
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  dislike 2021-06-17 12:22:51
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2   scared 2021-04-18 05:13:58
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust 2021-01-06 19:13:01
#
#                                 User ID Content_Type  Category    Sr  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying   NaN
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying   2.0
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  11.0
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  14.0
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying   2.0
#
#   Sentiment  Score
# 0       NaN    NaN
# 1  negative    0.0
# 2  negative   10.0
# 3  negative   15.0
# 4  negative    0.0

# %%
Answer.drop('Sr', inplace=True, axis=1)

# %%
Answer.shape
# Out:
# (25553, 8)

# %%
Answer.Type.unique()
# Out:
# array([nan, 'disgust', 'dislike', 'scared', 'interested', 'peeking',
#        'cherish', 'hate', 'love', 'indifferent', 'super love',
#        'intrigued', 'worried', 'like', 'heart', 'want', 'adore'],
#       dtype=object)

# %%
Answer.Category.unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', '"culture"', 'Fitness', '"studying"',
#        'Veganism', '"animals"', 'Travel', '"soccer"', 'Education',
#        '"dogs"', 'Technology', 'Soccer', '"tennis"', 'Culture', '"food"',
#        'Food', '"technology"', 'Healthy Eating', '"cooking"', 'Science',
#        '"public speaking"', '"veganism"', 'Public Speaking', '"science"'],
#       dtype=object)

# %%
Answer['Category'] = Answer['Category'].str.replace('"animals"','Animals')
Answer['Category'] = Answer['Category'].str.replace('Animals','animals')

# %%
Answer.head()
# Out:
#                              Content ID     Type            Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2      NaN 2021-04-22 15:17:15
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust 2020-11-07 09:43:50
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  dislike 2021-06-17 12:22:51
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2   scared 2021-04-18 05:13:58
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust 2021-01-06 19:13:01
#
#                                 User ID Content_Type  Category Sentiment  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying       NaN
# 1  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 3  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
# 4  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying  negative
#
#    Score
# 0    NaN
# 1    0.0
# 2   10.0
# 3   15.0
# 4    0.0

# %%
Answer = Answer[pd.notnull(Answer.Type)]

# %%
Answer.to_excel(r"C:\Users\Vrushali Patil\OneDrive\Accenture Forage\Working\Answer.xlsx",index=False)
